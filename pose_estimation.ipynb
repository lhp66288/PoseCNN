# %% [markdown]
# # ROB 498-011/599-011 Project 3: Pose Estimation - PoseCNN
# Before we start, please put your name and UMID in following format
#
# : Firstname LASTNAME, #00000000   //   e.g.) Anthony OPIPARI, #12345678

# %% [markdown]
# **Your Answer:**
# Firstname Lastname, #UMID

# %% [markdown]
# # PoseCNN: A Classic end-to-end pose estimation network
#
# In this exercise you will implement an **end-to-end** object pose estimator, based on [PoseCNN](https://arxiv.org/abs/1711.00199), which consists of two stages - feature extraction with a backbone network and pose estimation represented by instance segmentation, 3D translation estimation, and 3D rotation estimation.
# We will train it to estimate the pose of a set of object classes and evaluate the estimation accuracy.

# %% [markdown]
# # Getting Started

# %% [markdown]
# ## Setup Code
# Before getting started, we need to run some boilerplate code to set up our environment, same as previous assignments. You'll need to rerun this setup code each time you start the notebook.
#
# First, run this cell load the autoreload extension. This allows us to edit .py source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from google.colab import drive
#       3 drive.mount("/content/drive")
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# Now recall the path in your Google Drive where you uploaded this notebook, fill it in below. If everything is working correctly then running the following cell should print the filenames from the assignment:
#
# ```
# ["p3_helper.py", "rob599", "pose_cnn.py", "pose_estimation.ipynb"]
# ```

# %%
import os
import sys

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2024WN folder and put all the files under P3 folder, then "2024WN/P3"
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '2024WN/P3'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = None
# GOOGLE_DRIVE_PATH = os.path.join("drive", "My Drive", GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
# print(os.listdir(GOOGLE_DRIVE_PATH))

LOCAL_PATH = 'E:/DeepRob/P3'
print(os.listdir(LOCAL_PATH))
# Add to sys so we can import .py files.
# sys.path.append(GOOGLE_DRIVE_PATH)

sys.path.append(LOCAL_PATH)
# Out:
# ['p3_helper.py', 'posecnn_model.pth', 'pose_cnn.py', 'pose_estimation.ipynb', 'PROPS-Pose-Dataset', 'PROPS-Pose-Dataset.tar.gz', 'rob599', '__pycache__']

# %% [markdown]
# Next, we install a couple packages to help with processing and visualizing object models.

# %%
import os


#os.environ['PYOPENGL_PLATFORM'] = 'egl'

# %pip install trimesh
# %pip install pyrender
# %pip install pyquaternion
# Out:
# Requirement already satisfied: trimesh in d:\anaconda\envs\python-3.11\lib\site-packages (4.4.9)
# Requirement already satisfied: numpy>=1.20 in d:\anaconda\envs\python-3.11\lib\site-packages (from trimesh) (1.26.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyrender in d:\anaconda\envs\python-3.11\lib\site-packages (0.1.45)
# Requirement already satisfied: freetype-py in d:\anaconda\envs\python-3.11\lib\site-packages (from pyrender) (2.5.1)
# Requirement already satisfied: imageio in d:\anaconda\envs\python-3.11\lib\site-packages (from pyrender) (2.35.1)
# Requirement already satisfied: networkx in d:\anaconda\envs\python-3.11\lib\site-packages (from pyrender) (3.2.1)
# Requirement already satisfied: numpy in d:\anaconda\envs\python-3.11\lib\site-packages (from pyrender) (1.26.3)
# Requirement already satisfied: Pillow in d:\anaconda\envs\python-3.11\lib\site-packages (from pyrender) (10.2.0)
# Requirement already satisfied: pyglet>=1.4.10 in d:\anaconda\envs\python-3.11\lib\site-packages (from pyrender) (2.0.17)
# Requirement already satisfied: PyOpenGL==3.1.0 in d:\anaconda\envs\python-3.11\lib\site-packages (from pyrender) (3.1.0)
# Requirement already satisfied: scipy in d:\anaconda\envs\python-3.11\lib\site-packages (from pyrender) (1.14.1)
# Requirement already satisfied: six in d:\anaconda\envs\python-3.11\lib\site-packages (from pyrender) (1.16.0)
# Requirement already satisfied: trimesh in d:\anaconda\envs\python-3.11\lib\site-packages (from pyrender) (4.4.9)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyquaternion in d:\anaconda\envs\python-3.11\lib\site-packages (0.9.9)
# Requirement already satisfied: numpy in d:\anaconda\envs\python-3.11\lib\site-packages (from pyquaternion) (1.26.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Once you have successfully mounted your Google Drive and located the path to this assignment, run the following cell to allow us to import from the `.py` files of this assignment. If it works correctly, it should print the message:
#
# ```
# Hello from pose_cnn.py!
# Hello from p3_helper.py!
# ```
#
# as well as the last edit time for the file `pose_cnn.py`.

# %%
import os
import time

os.environ["TZ"] = "US/Eastern"
time.process_time()

from pose_cnn import hello_pose_cnn
from p3_helper import hello_helper


hello_pose_cnn()
hello_helper()

pose_cnn_path = os.path.join(LOCAL_PATH, "pose_cnn.py")
pose_cnn_edit_time = time.ctime(
    os.path.getmtime(pose_cnn_path)
)
print("pose_cnn.py last edited on %s" % pose_cnn_edit_time)
# Out:
# Hello from pose_cnn.py!
# Hello from P3_helper.py!
# pose_cnn.py last edited on Wed Sep 11 12:56:01 2024

# %% [markdown]
# Load several useful packages that are used in this notebook:

# %%
import os
import time

import matplotlib.pyplot as plt
import torch
import torchvision

# %matplotlib inline

from p3_helper import *
from rob599 import reset_seed
from rob599.grad import rel_error

# for plotting
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # set default size of plots
plt.rcParams["font.size"] = 16
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# %% [markdown]
# We will use GPUs to accelerate our computation in this notebook. Run the following to make sure GPUs are enabled:

# %%
if torch.cuda.is_available():
    print("Good to go!")
    DEVICE = torch.device("cuda")
else:
    print("Please set GPU via Edit -> Notebook Settings.")
    DEVICE = torch.device("cpu")
# Out:
# Good to go!

# %% [markdown]
# ## Load PROPS Pose Dataset
# During the majority of our homework assignments so far, we have used the PROPS Classification or Detection datasets for image processing tasks.
#
# In order to train and evaluate object pose estimation models, we need a dataset where each image is annotated with a *set* of *pose labels*, where each pose label gives the 3DoF position and 3DoF orientation of some object in the image.
#
# We will use the [PROPS Pose](https://deeprob.org/datasets/props-pose/) dataset, which provides annotations of this form.
# Our PROPS Detection dataset is much smaller than typical benchmarking pose estimation datasets, and thus easier to manage in an homework assignment.
# PROPS comprises annotated bounding boxes for 10 object classes:
# `["master_chef_can", "cracker_box", "sugar_box", "tomato_soup_can", "mustard_bottle", "tuna_fish_can", "gelatin_box", "potted_meat_can", "mug", "large_marker"]`.
# The choice of these objects is inspired by the [YCB object and Model set](https://ieeexplore.ieee.org/document/7251504) commonly used in robotic perception models.
#
# We create a [`PyTorch Dataset`](https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset) class
# named `PROPSPoseDataset` in `rob599/PROPSPoseDataset.py` that will download the PROPS Pose dataset.
#
# Run the following two cells to set a few config parameters and then download the train/val sets for the PROPS Pose dataset.

# %%
import multiprocessing

# Set a few constants related to data loading.
NUM_CLASSES = 10
BATCH_SIZE = 4
NUM_WORKERS = multiprocessing.cpu_count()

# %%
from rob599 import PROPSPoseDataset
 
# NOTE: Set `download=True` for the first time when you set up Google Drive folder.
# Turn it back to `False` later for faster execution in the future.
# If this hangs, download and place data in your drive manually.
train_dataset = PROPSPoseDataset(
    LOCAL_PATH, "train",
    download=False  # True (for the first time)
) 
val_dataset = PROPSPoseDataset(LOCAL_PATH, "val")

print(f"Dataset sizes: train ({len(train_dataset)}), val ({len(val_dataset)})")
# Out:
# Dataset sizes: train (500), val (500)

# %% [markdown]
# This dataset will format each sample from the dataset as a dictionary containing the following keys:
#
#  - 'rgb': a numpy float32 array of shape (3, 480, 640) scaled to range [0,1]
#  - 'depth': a numpy int32 array of shape (1, 480, 640) in (mm)
#  - 'objs_id': a numpy uint8 array of shape (10,) containing integer ids for visible objects (1-10) and invisible objects (0)
#  - 'label': a numpy bool array of shape (11, 480, 640) containing instance segmentation for objects in the scene
#  - 'bbx': a numpy float64 array of shape (10, 4) containing (x, y, w, h) coordinates of object bounding boxes
#  - 'RTs': a numpy float64 array of shape (10, 3, 4) containing homogeneous transformation matrices per object into camera coordinate frame
#  - 'centermaps': a numpy float64 array of shape (30, 480, 640) containing (dx, dy, z) coordinates to each object's centroid
#  - 'centers': a numpy float64 array of shape (10, 2) containing (x, y) coordinates of object centroids projected to image plane
#
# This dataset assumes that the upper left of the image is the origin point (0, 0).

# %% [markdown]
# ### Visualize Dataset
#
# Now let's visualize a few samples from our validation set to make sure the images and labels are loaded correctly. In this next cell, we'll use the `visualize_dataset` function from `rob599/utils.py` to view the RGB observation and labeled pose labels for three random samples.
#
# In the below figure, the final column plots the centermaps for class 0, which corresponds to the master chef coffee can. This plot is included to give a sense of how the centermaps represent gradients towards the object's centroid.

# %%
from rob599 import reset_seed, visualize_dataset

reset_seed(0)

grid_vis = visualize_dataset(val_dataset,num_samples = 4,alpha = 0.25)
plt.axis('off')
plt.imshow(grid_vis)
plt.show()

# %% [markdown]
# ## Implementing PoseCNN
#
# Now that we have our dataset loaded and ready to use, we'll begin implementing a variant of the [PoseCNN](https://arxiv.org/abs/1711.00199) network. This architecture is designed to take an RGB color image as input and produce a [6 degrees-of-freedom pose](https://en.wikipedia.org/wiki/Six_degrees_of_freedom) estimate for each instance of an object within the scene from which the image was taken. To do this, PoseCNN uses 5 operations within the architecture. First, a backbone convolutional feature extraction network is used to produce a tensor representing learned features from the input image. Second, the extracted features are processed by an embedding branch to reduce the spatial resolution and memory overhead for downstream layers. Third, an instance segmentation branch uses the embedded features to identify regions in the image corresponding to each object instance (regions of interest). Fourth, the translations for each object instance are estimated using a translation branch along with the embedded features. Finally, a rotation branch uses the embedded features to estimate a rotation, in the form of a [quaternion](https://en.wikipedia.org/wiki/Quaternions_and_spatial_rotation), for each region of interest.
#
# Thr architecture is shown in more detail from Figure 2 of the [PoseCNN paper](https://arxiv.org/abs/1711.00199):
#
# ![architecture](https://deeprob.org/assets/images/posecnn_arch.png)
#
# Now, we will implement a variant of this architecture that performs each of the 5 operations using PyTorch and data from our `PROPSPoseDataset`. The remainder of the features for this project will be implemented in the `pose_cnn.py` file.

# %% [markdown]
# ## Implementing the Backbone and Feature Extraction Branch
#
# In the past project, you implemented a deep convolutional network from scratch. In this project, we'll use [torchvision's](https://pytorch.org/vision/stable/index.html) pretrained convolutional networks for our backbone convolutional feature extractor. Specifically, we'll use the [VGG16 model](https://arxiv.org/abs/1409.1556) as our feature extractor:

# %%
import torchvision.models as models

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)

# %% [markdown]
# We can inspect the definition of this model by referring to the [model's source code within torchvision](https://pytorch.org/vision/main/_modules/torchvision/models/vgg.html). From this definition, we can see that the `vgg16.features` variable stores the feature extraction portion of VGG16 before average pooling. We'll use this pretrained VGG16 model for our PoseCNN model's pretrained extraction backbone. Print out the layers in `vgg16.features` by running the code cell below:

# %%
vgg16.features
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace=True)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
#   (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): ReLU(inplace=True)
#   (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace=True)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace=True)
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): ReLU(inplace=True)
#   (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (27): ReLU(inplace=True)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace=True)
#   (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %% [markdown]
# Using this `vgg16` model as the `pretrained_network`, we implement PoseCNN's feature extraction branch for you in the `FeatureExtraction` class of `pose_cnn.py`. You should inspect this function to understand how the output `feature1` and `feature2` tensors are created. In addition, observe that we freeze the early layers of our pretrained network by setting the corresponding convolutional weights and bias to have `requires_grad=False`. Freezing these layers will speed up training and help reduce overfitting.
#
# We can inspect the expected sizes of `feature1` and `feature2` by passing the `FeatureExtraction` dummy input:

# %%
import torchvision.models as models
from pose_cnn import FeatureExtraction

# Based on PoseCNN section III.B, the output features should 
# be 1/8 and 1/16 the input's spatial resolution with 512 channels
print('feature1 expected shape: (N, {}, {}, {})'.format(512, 480//8, 640//8))
print('feature2 expected shape: (N, {}, {}, {})'.format(512, 480//16, 640//16))
print()

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
#创建实例，Init函数调用
feature_extractor = FeatureExtraction(pretrained_model=vgg16)

dummy_input = {'rgb': torch.zeros((2,3,480,640))}
#将数据传输给提取器时，forward调用
feature1, feature2 = feature_extractor(dummy_input)

print('feature1 shape:', feature1.shape)
print('feature2 shape:', feature2.shape)
# Out:
# feature1 expected shape: (N, 512, 60, 80)
# feature2 expected shape: (N, 512, 30, 40)
#
# feature1 shape: torch.Size([2, 512, 60, 80])
# feature2 shape: torch.Size([2, 512, 30, 40])

# %% [markdown]
# Before moving on to the embedding and segmentation branch, take a moment to connect our `feature1` and `feature2` variables with the PoseCNN figure 2 shown earlier in the notebook. Understanding which arrows corresponds to `feature1` and `feature2` will make the remaining networks more comprehensible.

# %% [markdown]
# ## Implementing Segmentation Branch
#
# Now that we have our feature extractor setup, we'll implement the instnace segmentation branch. This branch should fuse information from the feature extractor (`feature1` and `feature2`) according to the architecture diagram of PoseCNN. Specifically, the network will pass both outputs from the feature extractor through a 1x1 convolution+ReLU layer followed by interpolation and an element wise addition. Next these intermediate features are interpolated back to the input image size followed by a final 1x1 convolution+ReLU layer to predict a probability for each class or background at each pixel. Follow the instructions in the `SegmentationBranch` class of `pose_cnn.py` to implement this branch.

# %%
import torchvision.models as models
from rob599 import reset_seed
from pose_cnn import FeatureExtraction, SegmentationBranch

reset_seed(0)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)

#实例化feature_extractor，执行FeatureExtraction的Init函数
feature_extractor = FeatureExtraction(pretrained_model=vgg16)

#实例化segmentation_branch，执行segmentation_branch的Init函数
segmentation_branch = SegmentationBranch()

dummy_input = {'rgb': torch.zeros((2,3,480,640))}

#执行FeatureExtraction的forward函数，获得两个特征图
feature1, feature2 = feature_extractor(dummy_input)

#执行segmentation_branch的forward函数
probability, segmentation, bbx = segmentation_branch(feature1, feature2)

print('probability expected shape: (B, 11, 480, 640)')
print('segmentation expected shape: (B, 480, 640)')
print('bbx expected shape: (N, 6) (where N is the number of rois extracted from the predicted segmentation)')
print()
print('probability shape:', probability.shape)
print('segmentation shape:', segmentation.shape)
print('bbx shape:', bbx.shape)
# Out:
# probability expected shape: (B, 11, 480, 640)
# segmentation expected shape: (B, 480, 640)
# bbx expected shape: (N, 6) (where N is the number of rois extracted from the predicted segmentation)
#
# probability shape: torch.Size([2, 11, 480, 640])
# segmentation shape: torch.Size([2, 480, 640])
# bbx shape: torch.Size([6, 6])

# %% [markdown]
# ### Adding Instance Segmentation Branch to PoseCNN
#
# Now that we have our instance segmentation branch implemented, we can begin building up our `PoseCNN` class. In `pose_cnn.py` use the given `FeatureExtraction` class and your implemented `SegmentationBranch` to initialize the extraction and segmentation portion of PoseCNN. Next, implement the training and testing time forward pass of `PoseCNN` to perform only instance segmentation. We will come back and add rotation+translation branches once we are confident in our instance segmentation.

# %% [markdown]
# ### Training PoseCNN to Perform Instance Segmentation
#
# Once you've added code to initialize and perform the forward pass of PoseCNN for feature extraction and instance segmentation, we can attempt to train this part of PoseCNN by itself. The code in the following cell will initialize a PoseCNN model and begin training it on instance segmentation only. You should expect to see your training loss decrease to ~0.1 after training for 2 epochs.

# %%
import time
from torch.utils.data import DataLoader
import torchvision.models as models

from rob599 import reset_seed
from pose_cnn import PoseCNN
from tqdm import tqdm

reset_seed(0)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1).to(DEVICE)
posecnn_model = PoseCNN(pretrained_backbone = vgg16,
                       models_pcd = torch.tensor(train_dataset.models_pcd).to(DEVICE, dtype=torch.float32),
                       cam_intrinsic = train_dataset.cam_intrinsic).to(DEVICE)

dataloader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE)
optimizer = torch.optim.Adam(posecnn_model.parameters(), lr=0.001,
                                 betas=(0.9, 0.999))

posecnn_model.train()

loss_history = []
log_period = 5
_iter = 0

st_time = time.time()
for epoch in range(3):
    train_loss = []
    for batch in tqdm(dataloader):
        for item in batch:
            batch[item] = batch[item].to(DEVICE)
        loss_dict = posecnn_model(batch)
        optimizer.zero_grad()
        total_loss = loss_dict["loss_segmentation"]
        total_loss.backward()
        optimizer.step()
        train_loss.append(total_loss.item())
    
        if _iter % log_period == 0:
            loss_history.append(total_loss.item())
        _iter += 1
    
    print('Time {0}'.format(time.strftime("%Hh %Mm %Ss", time.gmtime(time.time() - st_time)) + \
                                  ', ' + 'Epoch %02d' % epoch + ', ' + 'Training finished' + f' , with mean training loss {np.array(train_loss).mean()}'))
    
plt.title("Training loss history")
plt.xlabel(f"Iteration (x {log_period})")
plt.ylabel("Loss")
plt.plot(loss_history)
plt.show()
# Out:
# 100%|██████████| 125/125 [02:28<00:00,  1.18s/it]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 44
#      40             loss_history.append(total_loss.item())
#      41         _iter += 1
#      43     print('Time {0}'.format(time.strftime("%Hh %Mm %Ss", time.gmtime(time.time() - st_time)) + \
# ---> 44                                   ', ' + 'Epoch %02d' % epoch + ', ' + 'Training finished' + f' , with mean training loss {np.array(train_loss).mean()}'))
#      46 plt.title("Training loss history")
#      47 plt.xlabel(f"Iteration (x {log_period})")
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### Inference for Instance Segmentation
#
# Now that we have our segmentation network trained, we can qualitatively evaluate the segmentation results. The following notebook cell will visualize output segmentations on a sample from the validation set.

# %%
from torchvision.utils import make_grid

reset_seed(0)

num_samples = 3
posecnn_model.eval()

plt.text(300, -40, 'RGB', ha="center")
plt.text(950, -40, 'True\nSegmentation', ha="center")
plt.text(1600, -40, 'Predicted\nSegmentation', ha="center")

samples = []
for sample_i in range(num_samples):
    sample_idx = random.randint(0,len(val_dataset)-1)
    sample = val_dataset[sample_idx]
    
    rgb = torch.tensor(sample['rgb'][None, :]).to(DEVICE)
    _, prediction = posecnn_model({'rgb': rgb})
    prediction = prediction.cpu().numpy().astype(np.float64)
    prediction /= prediction.max()
    prediction = (np.tile(prediction, (3, 1, 1)) * 255).astype(np.uint8)
    rgb = (sample['rgb'].transpose(1, 2, 0) * 255).astype(np.uint8)
    depth = ((np.tile(sample['depth'], (3, 1, 1)) / sample['depth'].max()) * 255).astype(np.uint8)
    segmentation = (sample['label']*np.arange(11).reshape((11,1,1))).sum(0,keepdims=True).astype(np.float64)
    segmentation /= segmentation.max()
    segmentation = (np.tile(segmentation, (3, 1, 1)) * 255).astype(np.uint8)
    
    samples.append(torch.tensor(rgb.transpose(2, 0, 1)))
    samples.append(torch.tensor(segmentation))
    samples.append(torch.tensor(prediction))

img = make_grid(samples, nrow=3).permute(1, 2, 0)

plt.axis('off')
plt.imshow(img)
plt.show()

# %% [markdown]
# Before moving on, visually inspect the segmentation results above to ensure your forward functions and loss calculations are setup correctly.

# %% [markdown]
# ## Implementing the Translation Branch
#
# Now that we have our feature extractor and instance segmentation working, we'll implement the rotation and translation branches of PoseCNN. We suggest starting with the translation branch, which follows a similar embedding structure as was used for instance segmentation. Based on the architecture described in the paper, implement your translation network in the `TranslationBranch` class of `pose_cnn.py`.
#
# Once you have implemented `TranslationBranch`, the following notebook cell can be used to verify the shape of your output.

# %%
import torchvision.models as models
from rob599 import reset_seed
from pose_cnn import FeatureExtraction, TranslationBranch

reset_seed(0)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
feature_extractor = FeatureExtraction(pretrained_model=vgg16)
translation_branch = TranslationBranch()

dummy_input = {'rgb': torch.zeros((2,3,480,640))}
feature1, feature2 = feature_extractor(dummy_input)
translation = translation_branch(feature1, feature2)

print('translation expected shape: (2, 30, 480, 640)')
print()
print('translation shape:', translation.shape)
# Out:
# translation expected shape: (2, 30, 480, 640)
#
# translation shape: torch.Size([2, 30, 480, 640])

# %% [markdown]
# ## Implementing the Rotation Branch
#
# Now you can implement the final module of PoseCNN: the rotation branch. This portion of PoseCNN will be reminiscient of fasterRCNN in that we will predict a quaternion for each possible class at each region of interest detected by our preceeding segmentation branch. To do this, we'll need to use ROIPooling for feature extraction. Since you implemented ROIPooling in the last project, feel free to use the [ROIPool](https://pytorch.org/vision/main/generated/torchvision.ops.RoIPool.html) implemented by `torchvision.ops` for this project.
#
# Once you have implemented `RotationBranch`, the following notebook cell can be used to verify the shape of your output.

# %%
import torchvision.models as models
from rob599 import reset_seed
from pose_cnn import FeatureExtraction, RotationBranch

reset_seed(0)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
feature_extractor = FeatureExtraction(pretrained_model=vgg16)
rotation_branch = RotationBranch()

dummy_input = {'rgb': torch.zeros((2,3,480,640))}
dummy_bbx = torch.zeros((10,5)) # N = 10
feature1, feature2 = feature_extractor(dummy_input)
quaternion = rotation_branch(feature1, feature2, dummy_bbx)

print('quaternion expected shape: (N, 40)')
print()
print('quaternion shape:', quaternion.shape)
# Out:
# quaternion expected shape: (N, 40)
#
# quaternion shape: torch.Size([10, 40])

# %% [markdown]
# ## Hough Voting Layer
#
# One important piece of the PoseCNN architecture for inference time that we haven't implemented yet is a Hough voting layer. As described in the text, and illustrated below, a Hough voting layer is used during inference time to extract a single centroid prediction from the translation maps produced by `TranslationBranch` and the segments produced by `SegmentationBranch`. Due to the timing constraints of our semester, we have implemented this Hough voting layer for you in `P3_helper.py` as the `HoughVoting` function. We recommend you use our provided `HoughVoting` function after reading through its implementation to understand how it works
#
# ![hough](https://deeprob.org/assets/images/posecnn_hough.png)
#
# We also recommend reading through other given helper functions in `p3_helper.py` and the class definition of `PoseCNN` in `pose_cnn.py`. **Some of these utilities will be helpful for completing your PoseCNN implementation.**

# %% [markdown]
# ## Putting it all together: PoseCNN
#
# We now have all the modules needed to make up our PoseCNN architecture. In the `PoseCNN` class of `pose_cnn.py`, add the translation and rotation branches to the initialization and forward functions. During training, your PoseCNN model should output a `loss_dict` variable with loss values for segmentation, translation and rotation branches stored respectively with keys of `"loss_segmentation"`, `"loss_centermap"`, and `"loss_R"`. The segmentation loss should be calculated using `p3_helper.loss_cross_entropy`, the centroid loss should be calculated using l1Loss, and the rotation loss should be calculated using the provided helper in `p3_helper.loss_Rotation`. During inference, your model should output a dictionary of predicted poses (i.e. see `PoseCNN.generate_pose` for a formatting utility) in `output_dict` and the predicted segmentation map (post processed probabilities) in `segmentation`.
#
# After this, you will be ready to train your PoseCNN model with all three losses:

# %%
import os
import time
import torch
from torch.utils.data import DataLoader
import torchvision.models as models

import rob599
from pose_cnn import PoseCNN

rob599.reset_seed(0)

dataloader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
posecnn_model = PoseCNN(pretrained_backbone = vgg16, 
                models_pcd = torch.tensor(train_dataset.models_pcd).to(DEVICE, dtype=torch.float32),
                cam_intrinsic = train_dataset.cam_intrinsic).to(DEVICE)
posecnn_model.train()
    
optimizer = torch.optim.Adam(posecnn_model.parameters(), lr=0.001,
                            betas=(0.9, 0.999))


loss_history = []
log_period = 5
_iter = 0


st_time = time.time()
for epoch in range(10):
    train_loss = []
    dataloader.dataset.dataset_type = 'train'
    for batch in dataloader:
        for item in batch:
            batch[item] = batch[item].to(DEVICE)
        loss_dict = posecnn_model(batch)
        optimizer.zero_grad()
        total_loss = 0
        for loss in loss_dict:
            total_loss += loss_dict[loss]
        total_loss.backward()
        optimizer.step()
        train_loss.append(total_loss.item())
        
        if _iter % log_period == 0:
            loss_str = f"[Iter {_iter}][loss: {total_loss:.3f}]"
            for key, value in loss_dict.items():
                loss_str += f"[{key}: {value:.3f}]"

            print(loss_str)
            loss_history.append(total_loss.item())
        _iter += 1
        
    print('Time {0}'.format(time.strftime("%Hh %Mm %Ss", time.gmtime(time.time() - st_time)) + \
                                  ', ' + 'Epoch %02d' % epoch + ', ' + 'Training finished' + f' , with mean training loss {np.array(train_loss).mean()}'))    

torch.save(posecnn_model.state_dict(), os.path.join(LOCAL_PATH, "posecnn_model.pth"))
    
plt.title("Training loss history")
plt.xlabel(f"Iteration (x {log_period})")
plt.ylabel("Loss")
plt.plot(loss_history)
plt.show()
# Out:
# [Iter 0][loss: 3.684][loss_segmentation: 2.854][loss_centermap: 0.830][loss_R: 0.000]
# [Iter 5][loss: 1.857][loss_segmentation: 1.175][loss_centermap: 0.682][loss_R: 0.000]
# [Iter 10][loss: 1.129][loss_segmentation: 0.815][loss_centermap: 0.314][loss_R: 0.000]
# [Iter 15][loss: 0.933][loss_segmentation: 0.734][loss_centermap: 0.199][loss_R: 0.000]
# [Iter 20][loss: 0.873][loss_segmentation: 0.671][loss_centermap: 0.202][loss_R: 0.000]
# [Iter 25][loss: 0.885][loss_segmentation: 0.701][loss_centermap: 0.184][loss_R: 0.000]
# [Iter 30][loss: 0.770][loss_segmentation: 0.624][loss_centermap: 0.145][loss_R: 0.000]
# [Iter 35][loss: 0.735][loss_segmentation: 0.607][loss_centermap: 0.129][loss_R: 0.000]
# [Iter 40][loss: 0.668][loss_segmentation: 0.535][loss_centermap: 0.134][loss_R: 0.000]
# [Iter 45][loss: 0.739][loss_segmentation: 0.496][loss_centermap: 0.148][loss_R: 0.095]
# [Iter 50][loss: 0.541][loss_segmentation: 0.413][loss_centermap: 0.129][loss_R: 0.000]
# [Iter 55][loss: 0.564][loss_segmentation: 0.444][loss_centermap: 0.120][loss_R: 0.000]
# [Iter 60][loss: 0.527][loss_segmentation: 0.414][loss_centermap: 0.113][loss_R: 0.000]
# [Iter 65][loss: 0.556][loss_segmentation: 0.386][loss_centermap: 0.103][loss_R: 0.067]
# [Iter 70][loss: 0.520][loss_segmentation: 0.393][loss_centermap: 0.127][loss_R: 0.000]
# [Iter 75][loss: 0.482][loss_segmentation: 0.282][loss_centermap: 0.115][loss_R: 0.085]
# [Iter 80][loss: 0.516][loss_segmentation: 0.303][loss_centermap: 0.126][loss_R: 0.086]
# [Iter 85][loss: 0.452][loss_segmentation: 0.300][loss_centermap: 0.152][loss_R: 0.000]
# [Iter 90][loss: 0.369][loss_segmentation: 0.287][loss_centermap: 0.082][loss_R: 0.000]
# [Iter 95][loss: 0.395][loss_segmentation: 0.279][loss_centermap: 0.116][loss_R: 0.000]
# [Iter 100][loss: 0.493][loss_segmentation: 0.296][loss_centermap: 0.108][loss_R: 0.089]
# [Iter 105][loss: 0.370][loss_segmentation: 0.276][loss_centermap: 0.095][loss_R: 0.000]
# [Iter 110][loss: 0.381][loss_segmentation: 0.270][loss_centermap: 0.111][loss_R: 0.000]
# [Iter 115][loss: 0.406][loss_segmentation: 0.243][loss_centermap: 0.110][loss_R: 0.053]
# [Iter 120][loss: 0.310][loss_segmentation: 0.238][loss_centermap: 0.073][loss_R: 0.000]
# Time 00h 02m 22s, Epoch 00, Training finished , with mean training loss nan
# [Iter 125][loss: 0.398][loss_segmentation: 0.245][loss_centermap: 0.113][loss_R: 0.040]
# [Iter 130][loss: 0.357][loss_segmentation: 0.198][loss_centermap: 0.091][loss_R: 0.068]
# [Iter 135][loss: 0.354][loss_segmentation: 0.192][loss_centermap: 0.090][loss_R: 0.073]
# [Iter 140][loss: 0.312][loss_segmentation: 0.170][loss_centermap: 0.082][loss_R: 0.060]
# [Iter 145][loss: 0.304][loss_segmentation: 0.150][loss_centermap: 0.093][loss_R: 0.061]
# [Iter 150][loss: 0.302][loss_segmentation: 0.167][loss_centermap: 0.079][loss_R: 0.057]
# [Iter 155][loss: 0.235][loss_segmentation: 0.108][loss_centermap: 0.076][loss_R: 0.051]
# [Iter 160][loss: 0.258][loss_segmentation: 0.117][loss_centermap: 0.074][loss_R: 0.067]
# [Iter 165][loss: 0.281][loss_segmentation: 0.124][loss_centermap: 0.081][loss_R: 0.076]
# [Iter 170][loss: 0.223][loss_segmentation: 0.088][loss_centermap: 0.083][loss_R: 0.051]
# [Iter 175][loss: 0.226][loss_segmentation: 0.086][loss_centermap: 0.093][loss_R: 0.047]
# [Iter 180][loss: 0.219][loss_segmentation: 0.089][loss_centermap: 0.082][loss_R: 0.048]
# [Iter 185][loss: 0.240][loss_segmentation: 0.095][loss_centermap: 0.091][loss_R: 0.054]
# [Iter 190][loss: 0.365][loss_segmentation: 0.217][loss_centermap: 0.106][loss_R: 0.042]
# [Iter 195][loss: 0.215][loss_segmentation: 0.101][loss_centermap: 0.069][loss_R: 0.045]
# [Iter 200][loss: 0.200][loss_segmentation: 0.084][loss_centermap: 0.080][loss_R: 0.036]
# [Iter 205][loss: 0.203][loss_segmentation: 0.074][loss_centermap: 0.087][loss_R: 0.042]
# [Iter 210][loss: 0.207][loss_segmentation: 0.086][loss_centermap: 0.088][loss_R: 0.033]
# [Iter 215][loss: 0.200][loss_segmentation: 0.081][loss_centermap: 0.077][loss_R: 0.043]
# [Iter 220][loss: 0.204][loss_segmentation: 0.074][loss_centermap: 0.092][loss_R: 0.038]
# [Iter 225][loss: 0.197][loss_segmentation: 0.097][loss_centermap: 0.065][loss_R: 0.035]
# [Iter 230][loss: 0.210][loss_segmentation: 0.087][loss_centermap: 0.080][loss_R: 0.044]
# [Iter 235][loss: 0.146][loss_segmentation: 0.060][loss_centermap: 0.050][loss_R: 0.036]
# [Iter 240][loss: 0.179][loss_segmentation: 0.075][loss_centermap: 0.062][loss_R: 0.041]
# [Iter 245][loss: 0.171][loss_segmentation: 0.066][loss_centermap: 0.065][loss_R: 0.040]
# Time 00h 05m 02s, Epoch 01, Training finished , with mean training loss 0.24180412530899048
# [Iter 250][loss: 0.168][loss_segmentation: 0.069][loss_centermap: 0.067][loss_R: 0.031]
# [Iter 255][loss: 0.150][loss_segmentation: 0.069][loss_centermap: 0.052][loss_R: 0.029]
# [Iter 260][loss: 0.149][loss_segmentation: 0.068][loss_centermap: 0.053][loss_R: 0.029]
# [Iter 265][loss: 0.173][loss_segmentation: 0.086][loss_centermap: 0.056][loss_R: 0.031]
# [Iter 270][loss: 0.163][loss_segmentation: 0.070][loss_centermap: 0.061][loss_R: 0.032]
# [Iter 275][loss: 0.166][loss_segmentation: 0.076][loss_centermap: 0.056][loss_R: 0.035]
# [Iter 280][loss: 0.147][loss_segmentation: 0.067][loss_centermap: 0.054][loss_R: 0.026]
# [Iter 285][loss: 0.165][loss_segmentation: 0.076][loss_centermap: 0.059][loss_R: 0.030]
# [Iter 290][loss: 0.150][loss_segmentation: 0.067][loss_centermap: 0.053][loss_R: 0.031]
# [Iter 295][loss: 0.147][loss_segmentation: 0.066][loss_centermap: 0.051][loss_R: 0.031]
# [Iter 300][loss: 0.135][loss_segmentation: 0.064][loss_centermap: 0.052][loss_R: 0.019]
# [Iter 305][loss: 0.142][loss_segmentation: 0.065][loss_centermap: 0.050][loss_R: 0.027]
# [Iter 310][loss: 0.132][loss_segmentation: 0.060][loss_centermap: 0.049][loss_R: 0.022]
# [Iter 315][loss: 0.135][loss_segmentation: 0.069][loss_centermap: 0.042][loss_R: 0.024]
# [Iter 320][loss: 0.131][loss_segmentation: 0.067][loss_centermap: 0.045][loss_R: 0.019]
# [Iter 325][loss: 0.158][loss_segmentation: 0.082][loss_centermap: 0.048][loss_R: 0.029]
# [Iter 330][loss: 0.157][loss_segmentation: 0.076][loss_centermap: 0.053][loss_R: 0.028]
# [Iter 335][loss: 0.132][loss_segmentation: 0.062][loss_centermap: 0.055][loss_R: 0.015]
# [Iter 340][loss: 0.166][loss_segmentation: 0.073][loss_centermap: 0.063][loss_R: 0.030]
# [Iter 345][loss: 0.114][loss_segmentation: 0.056][loss_centermap: 0.045][loss_R: 0.013]
# [Iter 350][loss: 0.133][loss_segmentation: 0.069][loss_centermap: 0.040][loss_R: 0.025]
# [Iter 355][loss: 0.123][loss_segmentation: 0.061][loss_centermap: 0.045][loss_R: 0.016]
# [Iter 360][loss: 0.111][loss_segmentation: 0.054][loss_centermap: 0.046][loss_R: 0.011]
# [Iter 365][loss: 0.126][loss_segmentation: 0.061][loss_centermap: 0.043][loss_R: 0.021]
# [Iter 370][loss: 0.136][loss_segmentation: 0.062][loss_centermap: 0.053][loss_R: 0.021]
# Time 00h 07m 46s, Epoch 02, Training finished , with mean training loss 0.14239616906642913
# [Iter 375][loss: 0.120][loss_segmentation: 0.060][loss_centermap: 0.047][loss_R: 0.012]
# [Iter 380][loss: 0.138][loss_segmentation: 0.067][loss_centermap: 0.053][loss_R: 0.018]
# [Iter 385][loss: 0.111][loss_segmentation: 0.060][loss_centermap: 0.038][loss_R: 0.012]
# [Iter 390][loss: 0.160][loss_segmentation: 0.091][loss_centermap: 0.060][loss_R: 0.009]
# [Iter 395][loss: 0.105][loss_segmentation: 0.055][loss_centermap: 0.037][loss_R: 0.013]
# [Iter 400][loss: 0.106][loss_segmentation: 0.060][loss_centermap: 0.035][loss_R: 0.011]
# [Iter 405][loss: 0.110][loss_segmentation: 0.054][loss_centermap: 0.038][loss_R: 0.017]
# [Iter 410][loss: 0.114][loss_segmentation: 0.054][loss_centermap: 0.041][loss_R: 0.019]
# [Iter 415][loss: 0.133][loss_segmentation: 0.075][loss_centermap: 0.046][loss_R: 0.012]
# [Iter 420][loss: 0.099][loss_segmentation: 0.049][loss_centermap: 0.035][loss_R: 0.015]
# [Iter 425][loss: 0.095][loss_segmentation: 0.048][loss_centermap: 0.036][loss_R: 0.011]
# [Iter 430][loss: 0.100][loss_segmentation: 0.047][loss_centermap: 0.036][loss_R: 0.017]
# [Iter 435][loss: 0.099][loss_segmentation: 0.048][loss_centermap: 0.036][loss_R: 0.016]
# [Iter 440][loss: 0.107][loss_segmentation: 0.050][loss_centermap: 0.045][loss_R: 0.012]
# [Iter 445][loss: 0.104][loss_segmentation: 0.049][loss_centermap: 0.043][loss_R: 0.013]
# [Iter 450][loss: 0.098][loss_segmentation: 0.055][loss_centermap: 0.032][loss_R: 0.011]
# [Iter 455][loss: 0.095][loss_segmentation: 0.047][loss_centermap: 0.036][loss_R: 0.011]
# [Iter 460][loss: 0.098][loss_segmentation: 0.047][loss_centermap: 0.036][loss_R: 0.015]
# [Iter 465][loss: 0.103][loss_segmentation: 0.050][loss_centermap: 0.042][loss_R: 0.011]
# [Iter 470][loss: 0.088][loss_segmentation: 0.047][loss_centermap: 0.032][loss_R: 0.009]
# [Iter 475][loss: 0.091][loss_segmentation: 0.050][loss_centermap: 0.031][loss_R: 0.011]
# [Iter 480][loss: 0.087][loss_segmentation: 0.048][loss_centermap: 0.030][loss_R: 0.009]
# [Iter 485][loss: 0.090][loss_segmentation: 0.044][loss_centermap: 0.038][loss_R: 0.007]
# [Iter 490][loss: 0.093][loss_segmentation: 0.047][loss_centermap: 0.035][loss_R: 0.011]
# [Iter 495][loss: 0.104][loss_segmentation: 0.046][loss_centermap: 0.046][loss_R: 0.012]
# Time 00h 10m 35s, Epoch 03, Training finished , with mean training loss 0.10498596334457397
# [Iter 500][loss: 0.099][loss_segmentation: 0.051][loss_centermap: 0.037][loss_R: 0.011]
# [Iter 505][loss: 0.107][loss_segmentation: 0.054][loss_centermap: 0.043][loss_R: 0.010]
# [Iter 510][loss: 0.089][loss_segmentation: 0.046][loss_centermap: 0.034][loss_R: 0.008]
# [Iter 515][loss: 0.095][loss_segmentation: 0.052][loss_centermap: 0.033][loss_R: 0.009]
# [Iter 520][loss: 0.089][loss_segmentation: 0.046][loss_centermap: 0.032][loss_R: 0.010]
# [Iter 525][loss: 0.117][loss_segmentation: 0.063][loss_centermap: 0.044][loss_R: 0.010]
# [Iter 530][loss: 0.092][loss_segmentation: 0.047][loss_centermap: 0.036][loss_R: 0.009]
# [Iter 535][loss: 0.106][loss_segmentation: 0.058][loss_centermap: 0.039][loss_R: 0.008]
# [Iter 540][loss: 0.104][loss_segmentation: 0.053][loss_centermap: 0.041][loss_R: 0.010]
# [Iter 545][loss: 0.094][loss_segmentation: 0.046][loss_centermap: 0.039][loss_R: 0.009]
# [Iter 550][loss: 0.089][loss_segmentation: 0.045][loss_centermap: 0.035][loss_R: 0.009]
# [Iter 555][loss: 0.092][loss_segmentation: 0.046][loss_centermap: 0.036][loss_R: 0.010]
# [Iter 560][loss: 0.093][loss_segmentation: 0.045][loss_centermap: 0.037][loss_R: 0.010]
# [Iter 565][loss: 0.106][loss_segmentation: 0.062][loss_centermap: 0.036][loss_R: 0.009]
# [Iter 570][loss: 0.087][loss_segmentation: 0.046][loss_centermap: 0.034][loss_R: 0.007]
# [Iter 575][loss: 0.087][loss_segmentation: 0.047][loss_centermap: 0.031][loss_R: 0.008]
# [Iter 580][loss: 0.095][loss_segmentation: 0.047][loss_centermap: 0.040][loss_R: 0.008]
# [Iter 585][loss: 0.096][loss_segmentation: 0.046][loss_centermap: 0.044][loss_R: 0.007]
# [Iter 590][loss: 0.097][loss_segmentation: 0.049][loss_centermap: 0.035][loss_R: 0.013]
# [Iter 595][loss: 0.087][loss_segmentation: 0.046][loss_centermap: 0.032][loss_R: 0.009]
# [Iter 600][loss: 0.089][loss_segmentation: 0.050][loss_centermap: 0.030][loss_R: 0.009]
# [Iter 605][loss: 0.081][loss_segmentation: 0.045][loss_centermap: 0.027][loss_R: 0.010]
# [Iter 610][loss: 0.091][loss_segmentation: 0.043][loss_centermap: 0.038][loss_R: 0.009]
# [Iter 615][loss: 0.106][loss_segmentation: 0.048][loss_centermap: 0.047][loss_R: 0.010]
# [Iter 620][loss: 0.089][loss_segmentation: 0.045][loss_centermap: 0.038][loss_R: 0.006]
# Time 00h 13m 21s, Epoch 04, Training finished , with mean training loss 0.09434214156866073
# [Iter 625][loss: 0.090][loss_segmentation: 0.045][loss_centermap: 0.035][loss_R: 0.009]
# [Iter 630][loss: 0.082][loss_segmentation: 0.047][loss_centermap: 0.028][loss_R: 0.007]
# [Iter 635][loss: 0.087][loss_segmentation: 0.045][loss_centermap: 0.035][loss_R: 0.007]
# [Iter 640][loss: 0.078][loss_segmentation: 0.044][loss_centermap: 0.027][loss_R: 0.006]
# [Iter 645][loss: 0.084][loss_segmentation: 0.047][loss_centermap: 0.032][loss_R: 0.005]
# [Iter 650][loss: 0.089][loss_segmentation: 0.046][loss_centermap: 0.038][loss_R: 0.005]
# [Iter 655][loss: 0.084][loss_segmentation: 0.046][loss_centermap: 0.032][loss_R: 0.007]
# [Iter 660][loss: 0.082][loss_segmentation: 0.047][loss_centermap: 0.028][loss_R: 0.007]
# [Iter 665][loss: 0.100][loss_segmentation: 0.056][loss_centermap: 0.035][loss_R: 0.010]
# [Iter 670][loss: 0.083][loss_segmentation: 0.046][loss_centermap: 0.029][loss_R: 0.008]
# [Iter 675][loss: 0.080][loss_segmentation: 0.044][loss_centermap: 0.032][loss_R: 0.005]
# [Iter 680][loss: 0.085][loss_segmentation: 0.045][loss_centermap: 0.032][loss_R: 0.007]
# [Iter 685][loss: 0.075][loss_segmentation: 0.042][loss_centermap: 0.028][loss_R: 0.005]
# [Iter 690][loss: 0.077][loss_segmentation: 0.046][loss_centermap: 0.026][loss_R: 0.004]
# [Iter 695][loss: 0.088][loss_segmentation: 0.045][loss_centermap: 0.037][loss_R: 0.006]
# [Iter 700][loss: 0.078][loss_segmentation: 0.046][loss_centermap: 0.027][loss_R: 0.006]
# [Iter 705][loss: 0.082][loss_segmentation: 0.044][loss_centermap: 0.031][loss_R: 0.007]
# [Iter 710][loss: 0.079][loss_segmentation: 0.043][loss_centermap: 0.031][loss_R: 0.004]
# [Iter 715][loss: 0.088][loss_segmentation: 0.047][loss_centermap: 0.034][loss_R: 0.007]
# [Iter 720][loss: 0.087][loss_segmentation: 0.048][loss_centermap: 0.033][loss_R: 0.006]
# [Iter 725][loss: 0.082][loss_segmentation: 0.049][loss_centermap: 0.030][loss_R: 0.004]
# [Iter 730][loss: 0.077][loss_segmentation: 0.044][loss_centermap: 0.025][loss_R: 0.008]
# [Iter 735][loss: 0.075][loss_segmentation: 0.042][loss_centermap: 0.025][loss_R: 0.008]
# [Iter 740][loss: 0.089][loss_segmentation: 0.047][loss_centermap: 0.035][loss_R: 0.008]
# [Iter 745][loss: 0.092][loss_segmentation: 0.045][loss_centermap: 0.038][loss_R: 0.010]
# Time 00h 16m 05s, Epoch 05, Training finished , with mean training loss 0.08507881408929825
# [Iter 750][loss: 0.076][loss_segmentation: 0.044][loss_centermap: 0.025][loss_R: 0.007]
# [Iter 755][loss: 0.076][loss_segmentation: 0.044][loss_centermap: 0.026][loss_R: 0.006]
# [Iter 760][loss: 0.075][loss_segmentation: 0.043][loss_centermap: 0.026][loss_R: 0.006]
# [Iter 765][loss: 0.090][loss_segmentation: 0.054][loss_centermap: 0.031][loss_R: 0.006]
# [Iter 770][loss: 0.072][loss_segmentation: 0.044][loss_centermap: 0.022][loss_R: 0.006]
# [Iter 775][loss: 0.074][loss_segmentation: 0.045][loss_centermap: 0.025][loss_R: 0.004]
# [Iter 780][loss: 0.076][loss_segmentation: 0.047][loss_centermap: 0.025][loss_R: 0.004]
# [Iter 785][loss: 0.074][loss_segmentation: 0.046][loss_centermap: 0.024][loss_R: 0.004]
# [Iter 790][loss: 0.074][loss_segmentation: 0.044][loss_centermap: 0.025][loss_R: 0.005]
# [Iter 795][loss: 0.078][loss_segmentation: 0.044][loss_centermap: 0.027][loss_R: 0.007]
# [Iter 800][loss: 0.074][loss_segmentation: 0.043][loss_centermap: 0.026][loss_R: 0.006]
# [Iter 805][loss: 0.086][loss_segmentation: 0.044][loss_centermap: 0.035][loss_R: 0.007]
# [Iter 810][loss: 0.079][loss_segmentation: 0.042][loss_centermap: 0.032][loss_R: 0.005]
# [Iter 815][loss: 0.108][loss_segmentation: 0.067][loss_centermap: 0.035][loss_R: 0.006]
# [Iter 820][loss: 0.095][loss_segmentation: 0.055][loss_centermap: 0.033][loss_R: 0.006]
# [Iter 825][loss: 0.090][loss_segmentation: 0.047][loss_centermap: 0.036][loss_R: 0.007]
# [Iter 830][loss: 0.080][loss_segmentation: 0.043][loss_centermap: 0.028][loss_R: 0.009]
# [Iter 835][loss: 0.083][loss_segmentation: 0.044][loss_centermap: 0.033][loss_R: 0.007]
# [Iter 840][loss: 0.082][loss_segmentation: 0.047][loss_centermap: 0.028][loss_R: 0.006]
# [Iter 845][loss: 0.070][loss_segmentation: 0.043][loss_centermap: 0.023][loss_R: 0.004]
# [Iter 850][loss: 0.081][loss_segmentation: 0.048][loss_centermap: 0.026][loss_R: 0.007]
# [Iter 855][loss: 0.082][loss_segmentation: 0.046][loss_centermap: 0.029][loss_R: 0.006]
# [Iter 860][loss: 0.079][loss_segmentation: 0.043][loss_centermap: 0.029][loss_R: 0.007]
# [Iter 865][loss: 0.085][loss_segmentation: 0.044][loss_centermap: 0.033][loss_R: 0.008]
# [Iter 870][loss: 0.096][loss_segmentation: 0.047][loss_centermap: 0.042][loss_R: 0.007]
# Time 00h 18m 37s, Epoch 06, Training finished , with mean training loss 0.08400330442190171
# [Iter 875][loss: 0.090][loss_segmentation: 0.051][loss_centermap: 0.032][loss_R: 0.007]
# [Iter 880][loss: 0.088][loss_segmentation: 0.050][loss_centermap: 0.032][loss_R: 0.006]
# [Iter 885][loss: 0.072][loss_segmentation: 0.044][loss_centermap: 0.023][loss_R: 0.005]
# [Iter 890][loss: 0.074][loss_segmentation: 0.043][loss_centermap: 0.024][loss_R: 0.007]
# [Iter 895][loss: 0.072][loss_segmentation: 0.043][loss_centermap: 0.023][loss_R: 0.005]
# [Iter 900][loss: 0.070][loss_segmentation: 0.043][loss_centermap: 0.022][loss_R: 0.005]
# [Iter 905][loss: 0.074][loss_segmentation: 0.045][loss_centermap: 0.025][loss_R: 0.005]
# [Iter 910][loss: 0.069][loss_segmentation: 0.045][loss_centermap: 0.020][loss_R: 0.005]
# [Iter 915][loss: 0.071][loss_segmentation: 0.044][loss_centermap: 0.022][loss_R: 0.004]
# [Iter 920][loss: 0.071][loss_segmentation: 0.043][loss_centermap: 0.023][loss_R: 0.005]
# [Iter 925][loss: 0.067][loss_segmentation: 0.042][loss_centermap: 0.021][loss_R: 0.004]
# [Iter 930][loss: 0.077][loss_segmentation: 0.043][loss_centermap: 0.027][loss_R: 0.007]
# [Iter 935][loss: 0.079][loss_segmentation: 0.045][loss_centermap: 0.028][loss_R: 0.005]
# [Iter 940][loss: 0.075][loss_segmentation: 0.045][loss_centermap: 0.026][loss_R: 0.004]
# [Iter 945][loss: 0.070][loss_segmentation: 0.044][loss_centermap: 0.023][loss_R: 0.004]
# [Iter 950][loss: 0.237][loss_segmentation: 0.200][loss_centermap: 0.031][loss_R: 0.006]
# [Iter 955][loss: 0.091][loss_segmentation: 0.053][loss_centermap: 0.030][loss_R: 0.007]
# [Iter 960][loss: 0.113][loss_segmentation: 0.065][loss_centermap: 0.040][loss_R: 0.008]
# [Iter 965][loss: 0.087][loss_segmentation: 0.047][loss_centermap: 0.034][loss_R: 0.006]
# [Iter 970][loss: 0.089][loss_segmentation: 0.051][loss_centermap: 0.032][loss_R: 0.005]
# [Iter 975][loss: 0.080][loss_segmentation: 0.049][loss_centermap: 0.025][loss_R: 0.006]
# [Iter 980][loss: 0.085][loss_segmentation: 0.051][loss_centermap: 0.028][loss_R: 0.006]
# [Iter 985][loss: 0.077][loss_segmentation: 0.043][loss_centermap: 0.029][loss_R: 0.005]
# [Iter 990][loss: 0.081][loss_segmentation: 0.044][loss_centermap: 0.030][loss_R: 0.006]
# [Iter 995][loss: 0.086][loss_segmentation: 0.044][loss_centermap: 0.036][loss_R: 0.006]
# Time 00h 21m 08s, Epoch 07, Training finished , with mean training loss 0.08240226203203202
# [Iter 1000][loss: 0.088][loss_segmentation: 0.048][loss_centermap: 0.035][loss_R: 0.006]
# [Iter 1005][loss: 0.078][loss_segmentation: 0.047][loss_centermap: 0.024][loss_R: 0.007]
# [Iter 1010][loss: 0.074][loss_segmentation: 0.044][loss_centermap: 0.025][loss_R: 0.006]
# [Iter 1015][loss: 0.063][loss_segmentation: 0.042][loss_centermap: 0.017][loss_R: 0.004]
# [Iter 1020][loss: 0.072][loss_segmentation: 0.043][loss_centermap: 0.025][loss_R: 0.005]
# [Iter 1025][loss: 0.076][loss_segmentation: 0.048][loss_centermap: 0.023][loss_R: 0.005]
# [Iter 1030][loss: 0.069][loss_segmentation: 0.043][loss_centermap: 0.021][loss_R: 0.005]
# [Iter 1035][loss: 0.069][loss_segmentation: 0.044][loss_centermap: 0.021][loss_R: 0.004]
# [Iter 1040][loss: 0.069][loss_segmentation: 0.043][loss_centermap: 0.019][loss_R: 0.006]
# [Iter 1045][loss: 0.065][loss_segmentation: 0.042][loss_centermap: 0.019][loss_R: 0.004]
# [Iter 1050][loss: 0.076][loss_segmentation: 0.042][loss_centermap: 0.029][loss_R: 0.005]
# [Iter 1055][loss: 0.082][loss_segmentation: 0.044][loss_centermap: 0.032][loss_R: 0.006]
# [Iter 1060][loss: 0.070][loss_segmentation: 0.041][loss_centermap: 0.025][loss_R: 0.004]
# [Iter 1065][loss: 0.077][loss_segmentation: 0.045][loss_centermap: 0.027][loss_R: 0.005]
# [Iter 1070][loss: 0.069][loss_segmentation: 0.043][loss_centermap: 0.022][loss_R: 0.004]
# [Iter 1075][loss: 0.076][loss_segmentation: 0.044][loss_centermap: 0.029][loss_R: 0.004]
# [Iter 1080][loss: 0.078][loss_segmentation: 0.043][loss_centermap: 0.030][loss_R: 0.005]
# [Iter 1085][loss: 0.075][loss_segmentation: 0.042][loss_centermap: 0.030][loss_R: 0.004]
# [Iter 1090][loss: 0.079][loss_segmentation: 0.044][loss_centermap: 0.030][loss_R: 0.005]
# [Iter 1095][loss: 0.066][loss_segmentation: 0.042][loss_centermap: 0.021][loss_R: 0.003]
# [Iter 1100][loss: 0.076][loss_segmentation: 0.046][loss_centermap: 0.027][loss_R: 0.004]
# [Iter 1105][loss: 0.066][loss_segmentation: 0.042][loss_centermap: 0.020][loss_R: 0.003]
# [Iter 1110][loss: 0.073][loss_segmentation: 0.041][loss_centermap: 0.025][loss_R: 0.007]
# [Iter 1115][loss: 0.080][loss_segmentation: 0.043][loss_centermap: 0.030][loss_R: 0.007]
# [Iter 1120][loss: 0.075][loss_segmentation: 0.042][loss_centermap: 0.027][loss_R: 0.005]
# Time 00h 23m 39s, Epoch 08, Training finished , with mean training loss 0.07435218995809555
# [Iter 1125][loss: 0.076][loss_segmentation: 0.043][loss_centermap: 0.029][loss_R: 0.005]
# [Iter 1130][loss: 0.071][loss_segmentation: 0.043][loss_centermap: 0.024][loss_R: 0.003]
# [Iter 1135][loss: 0.065][loss_segmentation: 0.041][loss_centermap: 0.020][loss_R: 0.004]
# [Iter 1140][loss: 0.073][loss_segmentation: 0.045][loss_centermap: 0.022][loss_R: 0.006]
# [Iter 1145][loss: 0.083][loss_segmentation: 0.047][loss_centermap: 0.031][loss_R: 0.005]
# [Iter 1150][loss: 0.070][loss_segmentation: 0.045][loss_centermap: 0.022][loss_R: 0.003]
# [Iter 1155][loss: 0.074][loss_segmentation: 0.049][loss_centermap: 0.021][loss_R: 0.004]
# [Iter 1160][loss: 0.075][loss_segmentation: 0.045][loss_centermap: 0.024][loss_R: 0.005]
# [Iter 1165][loss: 0.072][loss_segmentation: 0.045][loss_centermap: 0.022][loss_R: 0.004]
# [Iter 1170][loss: 0.065][loss_segmentation: 0.041][loss_centermap: 0.019][loss_R: 0.004]
# [Iter 1175][loss: 0.065][loss_segmentation: 0.042][loss_centermap: 0.018][loss_R: 0.005]
# [Iter 1180][loss: 0.070][loss_segmentation: 0.042][loss_centermap: 0.023][loss_R: 0.005]
# [Iter 1185][loss: 0.071][loss_segmentation: 0.041][loss_centermap: 0.024][loss_R: 0.005]
# [Iter 1190][loss: 0.080][loss_segmentation: 0.048][loss_centermap: 0.027][loss_R: 0.005]
# [Iter 1195][loss: 0.078][loss_segmentation: 0.042][loss_centermap: 0.031][loss_R: 0.005]
# [Iter 1200][loss: 0.066][loss_segmentation: 0.044][loss_centermap: 0.017][loss_R: 0.005]
# [Iter 1205][loss: 0.070][loss_segmentation: 0.042][loss_centermap: 0.025][loss_R: 0.004]
# [Iter 1210][loss: 0.077][loss_segmentation: 0.044][loss_centermap: 0.029][loss_R: 0.004]
# [Iter 1215][loss: 0.071][loss_segmentation: 0.044][loss_centermap: 0.021][loss_R: 0.005]
# [Iter 1220][loss: 0.064][loss_segmentation: 0.043][loss_centermap: 0.018][loss_R: 0.003]
# [Iter 1225][loss: 0.076][loss_segmentation: 0.047][loss_centermap: 0.023][loss_R: 0.006]
# [Iter 1230][loss: 0.066][loss_segmentation: 0.042][loss_centermap: 0.021][loss_R: 0.003]
# [Iter 1235][loss: 0.066][loss_segmentation: 0.040][loss_centermap: 0.022][loss_R: 0.004]
# [Iter 1240][loss: 0.065][loss_segmentation: 0.041][loss_centermap: 0.019][loss_R: 0.005]
# [Iter 1245][loss: 0.066][loss_segmentation: 0.041][loss_centermap: 0.020][loss_R: 0.004]
# Time 00h 26m 10s, Epoch 09, Training finished , with mean training loss 0.07067279541492462

# %% [markdown]
# ### Inference
#
# Visualize a few outputs from the full trained model. These could be improved if we used a larger model, trained for greater duration, and if we used ICP with depth data to refine the final estimates.

# %%
import torch
from torch.utils.data import DataLoader
import torchvision.models as models

import rob599
from pose_cnn import PoseCNN, eval


rob599.reset_seed(0)

dataloader = DataLoader(dataset=val_dataset, batch_size=BATCH_SIZE)

vgg16 = models.vgg16(weights=models.VGG16_Weights.IMAGENET1K_V1)
posecnn_model = PoseCNN(pretrained_backbone = vgg16, 
                models_pcd = torch.tensor(val_dataset.models_pcd).to(DEVICE, dtype=torch.float32),
                cam_intrinsic = val_dataset.cam_intrinsic).to(DEVICE)
#posecnn_model.load_state_dict(torch.load(os.path.join(LOCAL_PATH, "posecnn_model.pth")))

posecnn_model.load_state_dict(torch.load(os.path.join(LOCAL_PATH, "posecnn_model.pth"), map_location=DEVICE, weights_only=True))

num_samples = 5
for i in range(num_samples):
    out = eval(posecnn_model, dataloader, DEVICE)

    plt.axis('off')
    plt.imshow(out)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File d:\Anaconda\envs\posecnn\Lib\site-packages\OpenGL\latebind.py:41, in LateBind.__call__(self, *args, **named)
#      40 try:
# ---> 41     return self._finalCall( *args, **named )
#      42 except (TypeError,AttributeError) as err:
#
# TypeError: 'NoneType' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# ArgumentError                             Traceback (most recent call last)
# Cell In[9], line 23
#      21 num_samples = 5
#      22 for i in range(num_samples):
# ---> 23     out = eval(posecnn_model, dataloader, DEVICE)
#      25     plt.axis('off')
#      26     plt.imshow(out)
#
# File e:\DeepRob\P3\pose_cnn.py:535, in eval(model, dataloader, device, alpha)
#     533 poselist = []
#     534 rgb =  (rgb[0].cpu().numpy().transpose(1, 2, 0) * 255).astype(np.uint8)
# --> 535 return dataloader.dataset.visualizer.vis_oneview(
#     536     ipt_im = rgb,
#     537     obj_pose_dict = pose_dict[0],
#     538     alpha = alpha
#     539     )
#
# File e:\DeepRob\P3\rob599\utils.py:242, in Visualize.vis_oneview(self, ipt_im, obj_pose_dict, alpha, axis_len)
#     240         node.mesh.is_visible = True
#     241         self.scene.set_pose(node, pose=pose)
# --> 242 full_depth = self.render.render(self.scene, flags = pyrender.constants.RenderFlags.DEPTH_ONLY)
#     243 for obj_label in obj_pose_dict:
#     244     if obj_label in self.object_dict:
#
# File d:\Anaconda\envs\posecnn\Lib\site-packages\pyrender\offscreen.py:102, in OffscreenRenderer.render(self, scene, flags, seg_node_map)
#     100 if self._platform.supports_framebuffers():
#     101     flags |= RenderFlags.OFFSCREEN
# --> 102     retval = self._renderer.render(scene, flags, seg_node_map)
#     103 else:
#     104     self._renderer.render(scene, flags, seg_node_map)
#
# File d:\Anaconda\envs\posecnn\Lib\site-packages\pyrender\renderer.py:125, in Renderer.render(self, scene, flags, seg_node_map)
#     101 """Render a scene with the given set of flags.
#     102
#     103 Parameters
#    (...)
#     122     in linear units.
#     123 """
#     124 # Update context with meshes and textures
# --> 125 self._update_context(scene, flags)
#     127 # Render necessary shadow maps
#     128 if not bool(flags & RenderFlags.DEPTH_ONLY or flags & RenderFlags.SEG):
#
# File d:\Anaconda\envs\posecnn\Lib\site-packages\pyrender\renderer.py:755, in Renderer._update_context(self, scene, flags)
#     753 # Add new textures to context
#     754 for texture in mesh_textures - self._mesh_textures:
# --> 755     texture._add_to_context()
#     757 # Remove old textures from context
#     758 for texture in self._mesh_textures - mesh_textures:
#
# File d:\Anaconda\envs\posecnn\Lib\site-packages\pyrender\texture.py:184, in Texture._add_to_context(self)
#     181     fmt = GL_RGBA
#     183 # Generate the OpenGL texture
# --> 184 self._texid = glGenTextures(1)
#     185 glBindTexture(self.tex_type, self._texid)
#     187 # Flip data for OpenGL buffer
#
# File d:\Anaconda\envs\posecnn\Lib\site-packages\OpenGL\latebind.py:61, in Curry.__call__(self, *args, **named)
#      59 def __call__( self, *args, **named ):
#      60     """returns self.wrapperFunction( self.baseFunction, *args, **named )"""
# ---> 61     return self.wrapperFunction( self.baseFunction, *args, **named )
#
# File d:\Anaconda\envs\posecnn\Lib\site-packages\OpenGL\GL\exceptional.py:178, in glGenTextures(baseFunction, count, textures)
#     174 elif count == 1 and _configflags.SIZE_1_ARRAY_UNPACK:
#     175     # this traditionally returned a single int/long, so we'll continue to
#     176     # do so, even though it would be easier not to bother.
#     177     textures = _types.GLuint( 0 )
# --> 178     baseFunction( count, textures)
#     179     return textures.value
#     180 else:
#
# File d:\Anaconda\envs\posecnn\Lib\site-packages\OpenGL\latebind.py:45, in LateBind.__call__(self, *args, **named)
#      43 if self._finalCall is None:
#      44     self._finalCall = self.finalise()
# ---> 45 return self._finalCall( *args, **named )
#
# File d:\Anaconda\envs\posecnn\Lib\site-packages\OpenGL\wrapper.py:657, in Wrapper.finaliseCall.<locals>.wrapperCall(*args)
#     655 cArguments = cArgs
#     656 try:
# --> 657     result = wrappedOperation( *cArguments )
#     658 except ctypes.ArgumentError as err:
#     659     err.args = err.args + (cArguments,)
#
# File d:\Anaconda\envs\posecnn\Lib\site-packages\OpenGL\platform\baseplatform.py:402, in _NullFunctionPointer.__call__(self, *args, **named)
#     400 def __call__( self, *args, **named ):
#     401     if self.load():
# --> 402         return self( *args, **named )
#     403     else:
#     404         from OpenGL import error
#
# ArgumentError: ("argument 2: TypeError: No array-type handler for type _ctypes.type (value: <cparam 'P' (0x00000148E935E918)>) registered", (1, <cparam 'P' (0x00000148E935E918)>))

# %% [markdown]
# Finally, let's measure the quantitative accuracy of our trained model using the 5°5cm metric. That is, we'll count how many visible objects our model was able to predict correctly, where a correct prediction is defined as one with a rotation error of less than 5° and a translation error of less than 5cm.
#
# The instructor's model, trained with the hyperparameters above achieves 29.3%.

# %%
import math
import torch
from torch.utils.data import DataLoader
import torchvision.models as models

import pyquaternion
from tqdm import tqdm

import rob599
from pose_cnn import PoseCNN

rob599.reset_seed(0)

dataloader = DataLoader(dataset=val_dataset, batch_size=BATCH_SIZE)

posecnn_model.load_state_dict(torch.load(os.path.join(LOCAL_PATH, "posecnn_model.pth")))
posecnn_model.eval()

print('posecnn_model:', posecnn_model)

T_thresh = 5 # cm
R_thresh = 5 # deg

total =0
correct = 0
for batch in tqdm(dataloader):
    for item in batch:
        batch[item] = batch[item].to(DEVICE)
    pose_dict, segmentation = posecnn_model(batch)

    print('pose_dict:', pose_dict)
    for bidx in range(BATCH_SIZE):
        objs_visib = batch['objs_id'][bidx].cpu().tolist()
        objs_preds = sorted(list(pose_dict[bidx].keys()))
        for objidx, objs_id in enumerate(objs_visib):
            if objs_id==0:
                continue

            total += 1
            if objs_id not in objs_preds:
                continue
            RT_pred = pose_dict[bidx][objs_id]
            RT_true = batch['RTs'][bidx][objidx].cpu().numpy()

            # Translation error
            T_pred = RT_pred[:3,3]
            T_true = RT_true[:3,3]
            T_err = 100*np.linalg.norm(T_pred-T_true) # error in cm

            # Rotation error
            R_true = pyquaternion.Quaternion(matrix=RT_true[:3,:3],atol=1e-6)
            R_pred = pyquaternion.Quaternion(matrix=RT_pred[:3,:3],atol=1e-6)

            R_rel = R_pred * R_true.conjugate
            R_err = math.degrees(R_rel.angle)

            if T_err<T_thresh and R_err<R_thresh:
                correct+=1

print("Accuracy at 5°5cm:",correct/total)
# Out:
# C:\Users\liuhp\AppData\Local\Temp\ipykernel_9820\1077118988.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   posecnn_model.load_state_dict(torch.load(os.path.join(LOCAL_PATH, "posecnn_model.pth")))
# posecnn_model: PoseCNN(
#   (feature_extractor): FeatureExtraction(
#     (embedding1): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#     )
#     (embedding2): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (2): ReLU(inplace=True)
#       (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#     )
#   )
#   (segmentation_branch): SegmentationBranch(
#     (feat1): Sequential(
#       (0): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#     )
#     (feat2): Sequential(
#       (0): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#     )
#     (fin_prob): Sequential(
#       (0): Conv2d(64, 11, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#     )
#   )
#   (translation_branch): TranslationBranch(
#     (feat1): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#     )
#     (feat2): Sequential(
#       (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): ReLU()
#     )
#     (fin_prob): Sequential(
#       (0): Conv2d(128, 30, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (rotation_branch): RotationBranch(
#     (three_fc_layers): Sequential(
#       (0): Linear(in_features=25088, out_features=4096, bias=True)
#       (1): Linear(in_features=4096, out_features=4096, bias=True)
#       (2): Linear(in_features=4096, out_features=40, bias=True)
#     )
#     (roi1): RoIPool(output_size=(7, 7), spatial_scale=0.125)
#     (roi2): RoIPool(output_size=(7, 7), spatial_scale=0.0625)
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
# )
#   0%|          | 0/125 [00:01<?, ?it/s]
# pose_dict: {0: {1: array([[-6.45875931e-04,  9.99445736e-01,  3.32812928e-02,
#         -2.78738103e-02],
#        [ 6.48198009e-01,  2.57612467e-02, -7.61035800e-01,
#         -5.92974754e-01],
#        [-7.61471510e-01,  2.10812967e-02, -6.47855282e-01,
#          2.42970753e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00]]), 2: array([[-0.83421183, -0.04388034, -0.54969549,         nan],
#        [-0.37772956,  0.77171922,  0.51163447,         nan],
#        [ 0.40175986,  0.63444781, -0.66035223,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 3: array([[ 0.06592774,  0.90424269,  0.42189896,         nan],
#        [-0.74549699,  0.32567859, -0.58152193,         nan],
#        [-0.66324031, -0.27618593,  0.69558144,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 4: array([[-9.99156117e-01, -2.49855667e-02,  3.26032750e-02,
#                     nan],
#        [-4.10710573e-02,  6.20214820e-01, -7.83356130e-01,
#                     nan],
#        [-6.48444577e-04, -7.84034073e-01, -6.20717764e-01,
#                     nan],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00]]), 5: array([[-0.10169065, -0.99456722,  0.02224982,         nan],
#        [-0.63219744,  0.04733866, -0.77335984,         nan],
#        [ 0.76810503, -0.09270978, -0.63357675,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 6: array([[ 0.60694522,  0.23124954, -0.76035589,         nan],
#        [ 0.70268476, -0.60310805,  0.37748456,         nan],
#        [-0.37128371, -0.76340294, -0.52854908,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 8: array([[ 0.93613219,  0.34814402,  0.04952022,         nan],
#        [ 0.25662425, -0.58007932, -0.77307951,         nan],
#        [-0.24041736,  0.73641282, -0.63237309,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 9: array([[ 0.91575247, -0.39872375, -0.04916119, -0.05819624],
#        [ 0.28542301,  0.55960149,  0.77806163,  0.01974529],
#        [-0.28272095, -0.72654355,  0.62626135,  0.4845784 ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}, 1: {1: array([[ 0.7844367 , -0.61672533,  0.06564245, -0.34630121],
#        [-0.34300202, -0.51957071, -0.78255743, -0.02641692],
#        [ 0.51672888,  0.59135133, -0.61910832,  1.0723511 ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 2: array([[ 0.2218675 , -0.0466873 ,  0.97395843,         nan],
#        [ 0.63093352,  0.76843816, -0.10689098,         nan],
#        [-0.7434364 ,  0.6382187 ,  0.19994807,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 4: array([[ 0.45206583,  0.88933146,  0.0687457 ,         nan],
#        [ 0.58333558, -0.2364552 , -0.77705115,         nan],
#        [-0.67480081,  0.39138007, -0.62567186,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 5: array([[-0.7665205 ,  0.63924819,  0.06171003,         nan],
#        [ 0.37379152,  0.52221   , -0.7665354 ,         nan],
#        [-0.52223194, -0.56449842, -0.63923013,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 7: array([[ 0.99198496,  0.12587629,  0.01099978,         nan],
#        [ 0.08945461, -0.63813436, -0.76471078,         nan],
#        [-0.08923961,  0.75956559, -0.64427996,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 8: array([[-0.12343705, -0.98893785,  0.08225116,         nan],
#        [-0.62000883,  0.01214027, -0.78450096,         nan],
#        [ 0.77482414, -0.14783296, -0.6146487 ,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 9: array([[-0.17683172,  0.9826479 , -0.05597967,  0.18218285],
#        [-0.63991368, -0.07156849,  0.76510692, -0.10760394],
#        [ 0.74782431,  0.17111725,  0.64146531,  1.30810618],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}, 2: {1: array([[-0.48416936, -0.87419659,  0.0368855 ,  0.0269495 ],
#        [-0.54219794,  0.26667327, -0.79681051,  0.10795994],
#        [ 0.68673253, -0.40579048, -0.60310268,  0.98635185],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 2: array([[ 0.97697169, -0.04443332, -0.2086913 ,         nan],
#        [-0.09865218,  0.77318931, -0.62645519,         nan],
#        [ 0.18919337,  0.63261676,  0.75100058,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 3: array([[ 0.00247359, -0.98832887,  0.15231524, -0.14130722],
#        [-0.80633396,  0.08811694,  0.58485979, -0.01355144],
#        [-0.5914554 , -0.12426366, -0.79670525,  0.85935938],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 4: array([[ 0.87687451, -0.47675729,  0.06159236, -0.16562351],
#        [-0.24426739, -0.55224502, -0.79709417,  0.06318769],
#        [ 0.41403449,  0.68390656, -0.60070586,  0.60166651],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 5: array([[ 0.45707136,  0.88748443,  0.05879721,         nan],
#        [ 0.56373167, -0.23793101, -0.79094589,         nan],
#        [-0.68796241,  0.39466456, -0.60905445,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 6: array([[-0.9428196 , -0.26768574,  0.19858363,         nan],
#        [ 0.09589878, -0.78847528, -0.6075443 ,         nan],
#        [ 0.31920925, -0.55376077,  0.76906073,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 7: array([[ 0.17236692, -0.98394907,  0.0461936 ,         nan],
#        [-0.6411072 , -0.14766479, -0.75311136,         nan],
#        [ 0.7478444 ,  0.10019648, -0.65626931,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 8: array([[-0.96175611,  0.27001172,  0.04603305,         nan],
#        [ 0.12571168,  0.58444071, -0.80163938,         nan],
#        [-0.2433556 , -0.76519459, -0.5960331 ,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 9: array([[-0.98387802, -0.16777979, -0.06191879,         nan],
#        [ 0.05820021, -0.62775803,  0.77622968,         nan],
#        [-0.16910568,  0.76011163,  0.62740219,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}, 3: {1: array([[-0.96786499,  0.25127232,  0.00998612,         nan],
#        [ 0.14898562,  0.60495746, -0.78219551,         nan],
#        [-0.20258525, -0.75557178, -0.62295306,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 2: array([[ 0.07565522, -0.03703204, -0.99644613,         nan],
#        [-0.62907934,  0.77356648, -0.07651177,         nan],
#        [ 0.77365065,  0.63263226,  0.03522825,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 3: array([[-0.01154029, -0.45733291,  0.88922071,         nan],
#        [-0.77633208,  0.56457573,  0.28029042,         nan],
#        [-0.63021851, -0.68709594, -0.3615576 ,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 4: array([[-0.33020818, -0.94315755,  0.03763428,  0.23716504],
#        [-0.57954204,  0.1711098 , -0.79677629,  0.03724024],
#        [ 0.74504602, -0.28491274, -0.60310125,  1.0254873 ],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 5: array([[ 0.94238335, -0.33344984,  0.02692343, -0.0813165 ],
#        [-0.18466121, -0.58561039, -0.78927857,  0.14556342],
#        [ 0.27895147,  0.73883122, -0.61344469,  0.81198597],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 6: array([[-0.54071867, -0.12732869, -0.83151108,         nan],
#        [ 0.71308118, -0.59375668, -0.37278411,         nan],
#        [-0.44624916, -0.79450631,  0.41185117,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 7: array([[-0.89192009, -0.44700843,  0.06827901,         nan],
#        [-0.3311384 ,  0.54283333, -0.77180266,         nan],
#        [ 0.30793819, -0.71099609, -0.63218558,         nan],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]]), 9: array([[-0.14687812, -0.98747289, -0.05765363, -0.36331832],
#        [ 0.61133045, -0.13644266,  0.77952445, -0.07008041],
#        [-0.7776258 ,  0.0792497 ,  0.62371278,  1.25900578],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])}}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 48
#      46 T_pred = RT_pred[:3,3]
#      47 T_true = RT_true[:3,3]
# ---> 48 T_err = 100*np.linalg.norm(T_pred-T_true) # error in cm
#      50 # Rotation error
#      51 R_true = pyquaternion.Quaternion(matrix=RT_true[:3,:3],atol=1e-6)
#
# NameError: name 'np' is not defined

# %% [markdown]
# # Submit Your Work
# After completing this notebook, run the following cell to create a `.zip` file for you to download and turn in.
#
# **Please MANUALLY SAVE every `*.ipynb` and `*.py` files before executing the following cell:**

# %%
from rob599.submit import make_p3_submission

# TODO: Replace these with your actual uniquename and umid
uniquename = None
umid = None

make_p3_submission(GOOGLE_DRIVE_PATH, uniquename, umid)
